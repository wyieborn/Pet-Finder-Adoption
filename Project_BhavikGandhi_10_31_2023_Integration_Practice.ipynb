# %%
# !pip install mysql-connector-python
# Out:
# ...
#      ---------------------------------------- 0.0/527.0 kB ? eta -:--:--
#      ---------------------------------------- 0.0/527.0 kB ? eta -:--:--
#       --------------------------------------- 10.2/527.0 kB ? eta -:--:--
#      -- ---------------------------------- 30.7/527.0 kB 330.3 kB/s eta 0:00:02
#      -- ---------------------------------- 41.0/527.0 kB 281.8 kB/s eta 0:00:02
#      ----- ------------------------------- 71.7/527.0 kB 393.8 kB/s eta 0:00:02
#      --------- -------------------------- 143.4/527.0 kB 774.0 kB/s eta 0:00:01
#      --------------- -------------------- 225.3/527.0 kB 919.0 kB/s eta 0:00:01
#      ------------------- ---------------- 286.7/527.0 kB 983.9 kB/s eta 0:00:01
#      ------------------- ---------------- 286.7/527.0 kB 983.9 kB/s eta 0:00:01
#      --------------------- -------------- 317.4/527.0 kB 895.6 kB/s eta 0:00:01
#      ---------------------------------- --- 481.3/527.0 kB 1.2 MB/s eta 0:00:01
# ...

# %%
#import os
#import mysql.connector

# %%
#username = os.environ.get('')
#password = os.environ.get('')
#host = os.environ.get('')

# %%
#cnx = mysql.connector.connect(host = "DeepanshBathla",
#                              port = "3306",
#                              user = "root@localhost",
#                              passwd = "corequery123")

# %%
#auth_plugin='corequery123B'

# %%
#df = pd.read_sql_query('Select * FROM Table supplychain', cnx)

# %%
#!pip install pymysql

# %%
#import pymysql

# Create a cursor using the pymysql module
#cursor = pymysql.cursors.Cursor()

# %%
#import pymysql

# Create a database connection
#connection = pymysql.connect(
#    host='DeepanshBathla',
#    user='root@localhost',
#    password='corequery123',
#    database='regularjobsearch'
#)

# Create a cursor associated with the connection
#cursor = connection.cursor()

# Now you can use the cursor to execute SQL queries
#cursor.execute("SELECT * FROM your_table")

# %%
#import pymysql.cursorsenter 
#connection = pymysql.connect(host='localhost',
#                         user='root',
#                         password='corequery123',
#                         db='regularjobsearch',
#                         charset='utf8mb4',
#                         cursorclass=pymysql.cursors.DictCursor)

# %%
#import os
#import pymysql
#import pandas as pd

#host = os.getenv('MYSQL_HOST')
#port = os.getenv('MYSQL_PORT')
#user = os.getenv('MYSQL_USER')
#password = os.getenv('MYSQL_PASSWORD')
#database = os.getenv('MYSQL_DATABASE')

#conn = pymysql.connect(
#    host= DeepanshBathla,
#    port=int(3306),
#    user="root",
#    passwd="corequery123",
#    db="regularjobsearch",
#    charset='utf8mb4')

# %%
#df = pd.read_sql_query("SELECT * from regularjobsearch",
#    conn)

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt

# %%
data = pd.read_csv("C:/Users/Deepa/OneDrive/Desktop/Pet_Schedule_embeded.csv")
data
# Out:
#        Unnamed: 0  Type            Name  Age  Breed1  Breed2  Gender  Color1  \
# 0               0     2          Nibble    3     299       0       1       1
# 1               1     2     No Name Yet    1     265       0       1       1
# 2               2     1          Brisco    1     307       0       1       2
# 3               3     1            Miko    4     307       0       2       1
# 4               4     1          Hunter    1     307       0       1       1
# ...           ...   ...             ...  ...     ...     ...     ...     ...
# 14988       14988     2             NaN    2     266       0       3       1
# 14989       14989     2  Serato & Eddie   60     265     264       3       1
# 14990       14990     2         Monkies    2     265     266       3       5
# 14991       14991     2         Ms Daym    9     266       0       2       4
# 14992       14992     1            Fili    1     307     307       1       2
#
# ...

# %%
#import mysql.connector
#import sys
#from PIL import Image
#import base64
#import cStringIO
#import PIL.Image

#db = mysql.connector.connect(user='root', password='corequery123',
#                              host='localhost',
#                              database='coursematerial')

#image = Image.open('C:\Users\Abhi\Desktop\cbir-p\images.jpg')
#with open("C:/Users/Deepa/OneDrive/Desktop/kangaroo-4.jpg", "rb") as image_file:
#    encoded_string = base64.b64encode(image_file.read())

# %%
#import mysql.connector
#import sys
#from PIL import Image
#import base64
#import cStringIO
#import PIL.Image

#db = mysql.connector.connect(user='root', password='corequery123',
#                              host='localhost',
#                              database='coursematerial')


#with open("C:\Users\Deepa\OneDrive\Desktop\kangaroo-4.jpg", "rb") as image_file:
#    encoded_string = base64.b64encode(image_file.read())

#blob_value = open('C:\Users\Abhi\Desktop\cbir-p\images.jpg', 'rb').read()
#sql = 'INSERT INTO img(images) VALUES(%s)'    
#args = (encoded_string, )
#cursor=db.cursor()
#cursor.execute(sql,args)
#sql1='select * from img'
#cursor.execute(sql1)
#data=cursor.fetchall()
#print type(data[0][0])
#data1=base64.b64decode(data[0][0])
#file_like=cStringIO.StringIO(data1)
#img=PIL.Image.open(file_like)
#img.show()

#db.close()

# %%
# !pip install -U tensorflow-probability==0.6.0

# %%
# !pip install --upgrade tensorflow-probability
# Out:
# ...
#   Attempting uninstall: tensorflow-probability
#     Found existing installation: tensorflow-probability 0.6.0
#     Uninstalling tensorflow-probability-0.6.0:
#       Successfully uninstalled tensorflow-probability-0.6.0
# ...

# %%
# !pip install tensorflow

# %%
# !pip install -U dm-sonnet==1.23
# !pip install --upgrade tfp-nightly
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='pypi.org', port=443): Read timed out. (read timeout=15)")': /simple/dm-sonnet/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x00000221D36F4608>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/dm-sonnet/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x00000221D36E7DC8>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/dm-sonnet/
# ...

# %%
#import tensorflow_probability as tfp
#import tensorflow_datasets as tfds
#import tensorflow_addons as tfa
#import tensorflow_hub as hub
#from skimage import exposure
#import pandas as pd; pd.options.mode.chained_assignment = None
#import numpy as np
#import scipy

# %%
# !pip install --upgrade tensorflow-probability
# Out:
# Requirement already up-to-date: tensorflow-probability in c:\users\deepa\anaconda3\lib\site-packages (0.19.0)
# ...

# %%
from pymongo import MongoClient

# %%
client = MongoClient("mongodb+srv://c0895648U2:bVcY7u7crupw5ldr@cluster0.jdfz4fe.mongodb.net/?retryWrites=true&w=majority")

# %%
mydb = client["PetImages"]

# %%
mydb
# Out:
# Database(MongoClient(host=['ac-il77tip-shard-00-01.jdfz4fe.mongodb.net:27017', 'ac-il77tip-shard-00-02.jdfz4fe.mongodb.net:27017', 'ac-il77tip-shard-00-00.jdfz4fe.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-6kgci5-shard-0', ssl=True), 'PetImages')

# %%
import gridfs

# %%
fs = gridfs.GridFS(mydb)
file = "C:/Users/Deepa/OneDrive/Desktop/kangaroo-4.jpg"

# %%
with open(file, 'rb') as f:
    contents = f.read()

# %%
fs.put(contents, filename="file")
# Out:
# ObjectId('654b4d4ec97bc6d5569dba0e')
